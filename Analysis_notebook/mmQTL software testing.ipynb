# %% [markdown]
# #  This notebook is to test the mmQTL packages

# %%
ls
# Out:
# Untitled.ipynb

# %%
pwd
# Out:
# /sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/Analysis_notebook

# %%
cd ../MMQTL/Test_data_for_mmQTL

# %%
ls
# Out:
# core.75384  core.80337				   GRM
# core.75671  ENSG00000121933			   output
# core.75706  ENSG00000162384			   Phenotype
# core.77583  ENSG00000162738			   PolyQTL_output
# core.78955  gene_location_for_simulated_phenotype  test_genotype
# core.79337  Genotype				   test_phenotype_path

# %%
cat test_genotype
# Out:
# Genotype/simulated_genotype_chr1
# Genotype/simulated_genotype_chr1
# Genotype/simulated_genotype_chr1
# Genotype/simulated_genotype_chr1
# Genotype/simulated_genotype_chr1

# %%
cat test_phenotype_path
# Out:
# Phenotype/simulated_phenotype_chr1_1
# Phenotype/simulated_phenotype_chr1_2
# Phenotype/simulated_phenotype_chr1_3
# Phenotype/simulated_phenotype_chr1_4
# Phenotype/simulated_phenotype_chr1_5

# %%
MMQTL26 -h
# Out:
# Options:
# -h, --help                     show this help message and exit
# -o STRING,      specify the output file
# -z_cutoff DOUBLE, --z_cutoff DOUBLE, specify absolute z_score cutoff used to estimate covariance, the default is 2
# -p_cutoff DOUBLE, --p_cutoff DOUBLE, specify p-value cutoff to detect independent QTL when conducting conditional analysis, the default is 0.000001
# -p FILE, --y_file FILE, set the file which contains paths to phenotype files
# -covariate FILE, --covariate FILE, set the file which contains paths to covariate files
# -C FILE, --covariate FILE,      set the covariate matrix
# -a FILE, set gene annotation file
# -cov, --cov,  use cov to estimate covariance due to sample overlap. The default is cor
# -T STRING, --target STRING, set the feature to explore
# -grm_file FILE, --grm_file FILE, set the file which contains paths to plink-format genotype files
# -A STRING, set Meta analysis pattern, either fixed or random
# ...

# %%
head gene_location_for_simulated_phenotype
# Out:
# 1	53679771	53686289	ENSG00000162384
# 1	220141943	220220000	ENSG00000136628
# 1	229652329	229694442	ENSG00000135776
# 1	160370376	160398468	ENSG00000162738
# 1	209955661	209957904	ENSG00000162757
# 1	206680879	206762616	ENSG00000136653
# 1	6650784	6674667	ENSG00000162413
# 1	65713902	65881552	ENSG00000116675
# 1	112025970	112106584	ENSG00000121933
# 1	1353800	1357149	ENSG00000235098

# %%
ls ENSG00000162738
# Out:
# MMQTL_demo.output_peak_1_statistical_signal
# MMQTL_demo.output_peak_1_statistical_signal_summary_correlation
# MMQTL_demo.output_peak_2_statistical_signal

# %%
ls
# Out:
# core.75384  core.80337				   GRM
# core.75671  ENSG00000121933			   output
# core.75706  ENSG00000162384			   Phenotype
# core.77583  ENSG00000162738			   PolyQTL_output
# core.78955  gene_location_for_simulated_phenotype  test_genotype
# core.79337  Genotype				   test_phenotype_path

# %%
jobs

# %%
MMQTL26 -P test_phenotype_path -Z test_genotype  -a gene_location_for_simulated_phenotype  -T ENSG00000162738  -o MMQTL_demo.output
# Out:
# Run analysis for gene ENSG00000162738
# Prepare GRM file is over
# Come into conditional_analysis function to perform real QTL detection
# file is: ENSG00000162738/merged_genotype_phenotype_tissue_0, and the corresponding grm file is: NA
# Reading Files ...
# ## number of total individuals = 1500
# ## number of analyzed individuals = 1500
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs = 13861
# ## number of analyzed SNPs = 13861
# Reading SNPs==================================================100.00%
# Output file is: output/output_of_GEMMA_0_ENSG00000162738.assoc.txt
# I am here1
# Come into conditional_analysis function to perform real QTL detection
# file is: ENSG00000162738/merged_genotype_phenotype_tissue_1, and the corresponding grm file is: NA
# Reading Files ...
# ## number of total individuals = 1500
# ## number of analyzed individuals = 1500
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs = 13861
# ...
