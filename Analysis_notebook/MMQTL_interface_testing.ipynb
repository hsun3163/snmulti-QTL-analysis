# %%
import pandas as pd
import qtl.io
from pathlib import Path

def prepare_bed(df, bed_template_df, chr_subset=None):
    bed_df = pd.merge(bed_template_df, df, left_index=True, right_index=True)
    bed_df = bed_df.groupby('#chr', sort=False, group_keys=False).apply(lambda x: x.sort_values('start'))
    if chr_subset is not None:
        bed_df = bed_df[bed_df.chr.isin(chr_subset)]
    return bed_df

def load_and_preprocess_data(input_path, drop_columns):
    df = pd.read_csv(input_path, sep="	", skiprows=0)
    dc = [col for col in df.columns if col in drop_columns] # Take interscet between df.columns and drop_columns
    df = df.drop(dc,axis = 1) # drop the intersect
    if len(df.columns) < 2:
        raise ValueError("There are too few columns in the loaded dataframe, please check the delimiter of the input file. The default delimiter is tab")
    return df

def rename_samples_using_lookup(df, lookup_path):
    sample_participant_lookup = Path(lookup_path)
    if sample_participant_lookup.is_file():
        sample_participant_lookup_s = pd.read_csv(sample_participant_lookup, sep="\t", index_col=0, dtype={0:str,1:str})
        df.rename(columns=sample_participant_lookup_s.to_dict(), inplace=True)
    return df

def load_bed_template(input_path, phenotype_id_type):
    if sum(qtl.io.gtf_to_tss_bed(input_path, feature='gene', phenotype_id = "gene_id").index.duplicated()) > 0:
        raise valueerror(f"gtf file {input_path} needs to be collapsed into gene model by reference data processing module")

    bed_template_df_id = qtl.io.gtf_to_tss_bed(input_path, feature='transcript', phenotype_id="gene_id")
    bed_template_df_name = qtl.io.gtf_to_tss_bed(input_path, feature='transcript', phenotype_id="gene_name")
    bed_template_df = bed_template_df_id.merge(bed_template_df_name, on=["chr", "start", "end"])
    bed_template_df.columns = ["#chr", "start", "end", "gene_id", "gene_name"]
    bed_template_df = bed_template_df.set_index(phenotype_id_type, drop=False)

    return bed_template_df

# %%
sample_participant_lookup_s = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/snmulti_QTL_sample_participant_lookup", sep="\t", index_col=0, dtype={0:str,1:str})

# %%
df = load_and_preprocess_data('/hpc/users/sunh14/snmulti_QTL/output/molecular_phenotype/gene_exp_dreamlet/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.gz', ["#chr","chr", "start", "end","stop","annot.seqnames","annot.start","annot.end"]) # This function will drop any columns from the DF based on the drop_columns list, so it is good to make the list comprehensive to accomodate different source of inputs.    df.set_index(df.columns[0], inplace=True)

# %%
sample_participant_lookup_s.to_dict()["genotype_id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sample_participant_lookup_s.to_dict()["genotype_id"]
#
# KeyError: 'genotype_id'

# %%
bed_df.rename(columns=sample_participant_lookup_s.to_dict()["participant_id"], inplace=True)

# %%
bed_df
# Out:
#            #chr    start      end               ID  \
# SLC6A13   chr12   262872   262873  ENSG00000010379
# CCDC77    chr12   389272   389273  ENSG00000120647
# KDM5A     chr12   389319   389320  ENSG00000073614
# B4GALNT3  chr12   459938   459939  ENSG00000139044
# NINJ2     chr12   663778   663779  ENSG00000171840
# ...         ...      ...      ...              ...
# MT-ND4    chrMT    10759    10760  ENSG00000198886
# MT-ND5    chrMT    12336    12337  ENSG00000198786
# MT-ND6    chrMT    14672    14673  ENSG00000198695
# MT-CYB    chrMT    14746    14747  ENSG00000198727
# ZFY        chrY  2935280  2935281  ENSG00000067646
#
#           G-MSBB-MB000312-BR-MSBB-71973    144547  \
# SLC6A13                        2.172658  1.709359
# CCDC77                         3.226371  3.093995
# KDM5A                          7.058730  7.293998
# B4GALNT3                       0.858992  0.104313
# NINJ2                          4.546701  0.598382
# ...                                 ...       ...
# MT-ND4                         6.603008  5.736608
# MT-ND5                         5.983093  3.692530
# MT-ND6                         2.952752  1.258270
# MT-CYB                         5.381846  4.440262
# ZFY                           -0.442486  0.104313
#
#           G-MSBB-MB000254-BR-MSBB-71909  G-MSBB-MB000266-BR-MSBB-71923  \
# SLC6A13                        3.045770                      -2.344371
# CCDC77                         2.331558                       3.317291
# KDM5A                          6.800099                       6.851682
# B4GALNT3                       1.774543                      -2.344371
# NINJ2                          0.855276                       3.002470
# ...                                 ...                            ...
# MT-ND4                         5.281309                       5.365801
# MT-ND5                         4.699995                       4.439164
# MT-ND6                         1.774543                       1.105082
# MT-CYB                         3.045770                       4.975634
# ZFY                            4.508910                       4.439164
#
#           G-MSBB-MB000009-BR-MSBB-68427  G-MSBB-MB000016-BR-MSBB-68454  ...  \
# SLC6A13                        2.504080                       0.010192  ...
# CCDC77                         3.795644                       3.423472  ...
# KDM5A                          7.050204                       6.937034  ...
# B4GALNT3                       1.943941                      -2.344369  ...
# NINJ2                         -2.344369                       1.393660  ...
# ...                                 ...                            ...  ...
# MT-ND4                         3.973807                       6.126645  ...
# MT-ND5                         3.072252                       4.751289  ...
# MT-ND6                         1.015950                       2.739487  ...
# MT-CYB                         3.355605                       4.915208  ...
# ZFY                            0.150005                       5.130705  ...
#
#           G-MSBB-MB000162-BR-MSBB-71803  G-MSBB-MB000036-BR-MSBB-70609  \
# SLC6A13                        2.256165                       1.027481
# CCDC77                         3.444169                       3.233375
# KDM5A                          6.898261                       6.310767
# B4GALNT3                      -2.344370                       2.516408
# NINJ2                         -2.344370                       3.491366
# ...                                 ...                            ...
# MT-ND4                         4.529717                       7.275072
# MT-ND5                         3.444169                       6.170272
# MT-ND6                         0.785487                       4.067884
# MT-CYB                         2.256165                       6.611748
# ZFY                           -2.344370                       1.027481
#
#           G-MSBB-MB000048-BR-MSBB-71677  G-MSBB-MB000163-BR-MSBB-71804  \
# SLC6A13                        0.447590                       1.743385
# CCDC77                         2.445654                       3.093991
# KDM5A                          6.740973                       6.978000
# B4GALNT3                       0.961389                       1.821125
# NINJ2                          2.445654                       6.369578
# ...                                 ...                            ...
# MT-ND4                         5.812641                       7.532908
# MT-ND5                         5.088967                       6.007528
# MT-ND6                         2.592432                       3.062325
# MT-CYB                         3.767194                       6.602071
# ZFY                           -0.357832                      -0.409236
#
#               X579  G-MSBB-MB000278-BR-MSBB-71936  \
# SLC6A13   2.046195                       1.239864
# CCDC77    2.408746                       2.341367
# KDM5A     6.790785                       7.275972
# B4GALNT3  2.608046                       1.239864
# NINJ2     5.480347                       0.864375
# ...            ...                            ...
# MT-ND4    5.231229                       5.512820
# MT-ND5    4.395274                       4.710124
# MT-ND6    2.408746                       1.239864
# MT-CYB    4.892207                       4.217086
# ZFY       1.354372                      -2.344369
#
#           G-MSBB-MB000294-BR-MSBB-71952  G-MSBB-MB000227-BR-MSBB-71879  \
# SLC6A13                        2.102267                       2.393921
# CCDC77                         2.531974                       2.759905
# KDM5A                          7.048931                       6.692078
# B4GALNT3                       0.754206                      -0.508802
# NINJ2                         -0.086495                      -0.508802
# ...                                 ...                            ...
# MT-ND4                         5.971959                       5.776981
# MT-ND5                         3.985474                       4.316632
# MT-ND6                         0.394246                       1.902329
# MT-CYB                         5.603332                       5.607703
# ZFY                           -0.812585                       2.085443
#
#           G-MSBB-MB000234-BR-MSBB-71886  0_MSSM_167
# SLC6A13                       -0.603357   -2.344370
# CCDC77                         3.087538    2.996036
# KDM5A                          6.962894    6.944142
# B4GALNT3                       1.030083    1.726555
# NINJ2                          1.958795   -2.344370
# ...                                 ...         ...
# MT-ND4                         5.460123    5.852431
# MT-ND5                         3.305148    5.345496
# MT-ND6                         1.958795    2.282616
# MT-CYB                         4.256294    4.352466
# ZFY                            4.824597    5.105758
#
# [14455 rows x 191 columns]

# %%
df.set_index(df.columns[0], inplace=True)
df = rename_samples_using_lookup(df, "/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/snmulti_QTL_sample_participant_lookup")
bed_template_df = load_bed_template('/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.gtf', "gene_name")
bed_df = prepare_bed(df, bed_template_df).drop("gene_name", axis=1)
bed_df = bed_df.drop_duplicates("gene_id", keep=False)
bed_df = bed_df.rename(columns={'gene_id': 'ID'})
qtl.io.write_bed(bed_df, '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.bed.gz')
bed_df[["#chr","start","end","ID"]].assign(path = '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.bed.gz').to_csv('/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.region_list.txt',"\t",index = False)
# Out:
# /bin/sh: 1: bgzip: not found
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[7], line 7
#       5 bed_df = bed_df.drop_duplicates("gene_id", keep=False)
#       6 bed_df = bed_df.rename(columns={'gene_id': 'ID'})
# ----> 7 qtl.io.write_bed(bed_df, '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.bed.gz')
#       8 bed_df[["#chr","start","end","ID"]].assign(path = '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.bed.gz').to_csv('/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.region_list.txt',"\t",index = False)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/qtl/io.py:24, in write_bed(bed_df, output_name, header, float_format)
#      22     header = bed_df.columns.values.copy()
#      23     header[0] = '#chr'
# ---> 24 to_bgzip(bed_df, output_name, header=header, float_format=float_format)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/qtl/io.py:12, in to_bgzip(df, path, header, float_format)
#      10 assert path.endswith('.gz')
#      11 bgzip = subprocess.Popen('bgzip -c > '+path, stdin=subprocess.PIPE, shell=True, encoding='utf8')
# ---> 12 df.to_csv(bgzip.stdin, sep='\t', index=False, header=header, float_format=float_format)
#      13 stdout, stderr = bgzip.communicate()
#      14 subprocess.check_call('tabix -f '+path, shell=True)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:257, in CSVFormatter.save(self)
#     237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#    (...)
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
# --> 257     self._save()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:262, in CSVFormatter._save(self)
#     260 if self._need_to_save_header:
#     261     self._save_header()
# --> 262 self._save_body()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:300, in CSVFormatter._save_body(self)
#     298 if start_i >= end_i:
#     299     break
# --> 300 self._save_chunk(start_i, end_i)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:311, in CSVFormatter._save_chunk(self, start_i, end_i)
#     308 data = [res.iget_values(i) for i in range(len(res.items))]
#     310 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 311 libwriters.write_csv_rows(
#     312     data,
#     313     ix,
#     314     self.nlevels,
#     315     self.cols,
#     316     self.writer,
#     317 )
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/_libs/writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
bed_df
# Out:
#            #chr    start      end               ID      X197      X199  \
# SLC6A13   chr12   262872   262873  ENSG00000010379  2.172658  1.709359
# CCDC77    chr12   389272   389273  ENSG00000120647  3.226371  3.093995
# KDM5A     chr12   389319   389320  ENSG00000073614  7.058730  7.293998
# B4GALNT3  chr12   459938   459939  ENSG00000139044  0.858992  0.104313
# NINJ2     chr12   663778   663779  ENSG00000171840  4.546701  0.598382
# ...         ...      ...      ...              ...       ...       ...
# MT-ND4    chrMT    10759    10760  ENSG00000198886  6.603008  5.736608
# MT-ND5    chrMT    12336    12337  ENSG00000198786  5.983093  3.692530
# MT-ND6    chrMT    14672    14673  ENSG00000198695  2.952752  1.258270
# MT-CYB    chrMT    14746    14747  ENSG00000198727  5.381846  4.440262
# ZFY        chrY  2935280  2935281  ENSG00000067646 -0.442486  0.104313
#
#               X200      X202      X204      X206  ...      X555      X556  \
# SLC6A13   3.045770 -2.344371  2.504080  0.010192  ...  2.256165  1.027481
# CCDC77    2.331558  3.317291  3.795644  3.423472  ...  3.444169  3.233375
# KDM5A     6.800099  6.851682  7.050204  6.937034  ...  6.898261  6.310767
# B4GALNT3  1.774543 -2.344371  1.943941 -2.344369  ... -2.344370  2.516408
# NINJ2     0.855276  3.002470 -2.344369  1.393660  ... -2.344370  3.491366
# ...            ...       ...       ...       ...  ...       ...       ...
# MT-ND4    5.281309  5.365801  3.973807  6.126645  ...  4.529717  7.275072
# MT-ND5    4.699995  4.439164  3.072252  4.751289  ...  3.444169  6.170272
# MT-ND6    1.774543  1.105082  1.015950  2.739487  ...  0.785487  4.067884
# MT-CYB    3.045770  4.975634  3.355605  4.915208  ...  2.256165  6.611748
# ZFY       4.508910  4.439164  0.150005  5.130705  ... -2.344370  1.027481
#
#               X562      X577      X579      X582      X583      X586  \
# SLC6A13   0.447590  1.743385  2.046195  1.239864  2.102267  2.393921
# CCDC77    2.445654  3.093991  2.408746  2.341367  2.531974  2.759905
# KDM5A     6.740973  6.978000  6.790785  7.275972  7.048931  6.692078
# B4GALNT3  0.961389  1.821125  2.608046  1.239864  0.754206 -0.508802
# NINJ2     2.445654  6.369578  5.480347  0.864375 -0.086495 -0.508802
# ...            ...       ...       ...       ...       ...       ...
# MT-ND4    5.812641  7.532908  5.231229  5.512820  5.971959  5.776981
# MT-ND5    5.088967  6.007528  4.395274  4.710124  3.985474  4.316632
# MT-ND6    2.592432  3.062325  2.408746  1.239864  0.394246  1.902329
# MT-CYB    3.767194  6.602071  4.892207  4.217086  5.603332  5.607703
# ZFY      -0.357832 -0.409236  1.354372 -2.344369 -0.812585  2.085443
#
#               X588      X589
# SLC6A13  -0.603357 -2.344370
# CCDC77    3.087538  2.996036
# KDM5A     6.962894  6.944142
# B4GALNT3  1.030083  1.726555
# NINJ2     1.958795 -2.344370
# ...            ...       ...
# MT-ND4    5.460123  5.852431
# MT-ND5    3.305148  5.345496
# MT-ND6    1.958795  2.282616
# MT-CYB    4.256294  4.352466
# ZFY       4.824597  5.105758
#
# [14455 rows x 191 columns]

# %%
a = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.bed.gz",sep = "\t",usecols=[0, 1, 2, 3])

# %%
b = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/working/recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.region_list.txt","\t")
# Out:
# /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
b
# Out:
#         #chr    start      end               ID  \
# 0      chr12   262872   262873  ENSG00000010379
# 1      chr12   389272   389273  ENSG00000120647
# 2      chr12   389319   389320  ENSG00000073614
# 3      chr12   459938   459939  ENSG00000139044
# 4      chr12   663778   663779  ENSG00000171840
# ...      ...      ...      ...              ...
# 14450  chrMT    10759    10760  ENSG00000198886
# 14451  chrMT    12336    12337  ENSG00000198786
# 14452  chrMT    14672    14673  ENSG00000198695
# 14453  chrMT    14746    14747  ENSG00000198727
# 14454   chrY  2935280  2935281  ENSG00000067646
#
#                                                     path
# 0      /sc/arion/projects/CommonMind/roussp01a/snmult...
# 1      /sc/arion/projects/CommonMind/roussp01a/snmult...
# 2      /sc/arion/projects/CommonMind/roussp01a/snmult...
# 3      /sc/arion/projects/CommonMind/roussp01a/snmult...
# 4      /sc/arion/projects/CommonMind/roussp01a/snmult...
# ...                                                  ...
# 14450  /sc/arion/projects/CommonMind/roussp01a/snmult...
# 14451  /sc/arion/projects/CommonMind/roussp01a/snmult...
# 14452  /sc/arion/projects/CommonMind/roussp01a/snmult...
# 14453  /sc/arion/projects/CommonMind/roussp01a/snmult...
# 14454  /sc/arion/projects/CommonMind/roussp01a/snmult...
#
# [14455 rows x 5 columns]

# %%
bed_template_df = load_bed_template('/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.gtf', "gene_id")

# %%
bed_template_df
# Out:
#                   #chr  start    end          gene_id    gene_name
# gene_id
# ENSG00000223972   chr1  11868  11869  ENSG00000223972      DDX11L1
# ENSG00000278267   chr1  17435  17436  ENSG00000278267    MIR6859-1
# ENSG00000243485   chr1  29553  29554  ENSG00000243485  MIR1302-2HG
# ENSG00000227232   chr1  29569  29570  ENSG00000227232       WASH7P
# ENSG00000284332   chr1  30365  30366  ENSG00000284332    MIR1302-2
# ...                ...    ...    ...              ...          ...
# ENSG00000198695  chrMT  14672  14673  ENSG00000198695       MT-ND6
# ENSG00000210194  chrMT  14741  14742  ENSG00000210194        MT-TE
# ENSG00000198727  chrMT  14746  14747  ENSG00000198727       MT-CYB
# ENSG00000210195  chrMT  15887  15888  ENSG00000210195        MT-TT
# ENSG00000210196  chrMT  16022  16023  ENSG00000210196        MT-TP
#
# [60726 rows x 5 columns]

# %%
counts = b.groupby(['#chr',"path"]).size().reset_index()

# %%
a.merge(counts, left_on = "#chr",right_on = "#chr")
# Out:
#         #chr    start      end               ID  \
# 0      chr12   262872   262873  ENSG00000010379
# 1      chr12   389272   389273  ENSG00000120647
# 2      chr12   389319   389320  ENSG00000073614
# 3      chr12   459938   459939  ENSG00000139044
# 4      chr12   663778   663779  ENSG00000171840
# ...      ...      ...      ...              ...
# 14450  chrMT    10759    10760  ENSG00000198886
# 14451  chrMT    12336    12337  ENSG00000198786
# 14452  chrMT    14672    14673  ENSG00000198695
# 14453  chrMT    14746    14747  ENSG00000198727
# 14454   chrY  2935280  2935281  ENSG00000067646
#
#                                                     path    0
# 0      /sc/arion/projects/CommonMind/roussp01a/snmult...  773
# 1      /sc/arion/projects/CommonMind/roussp01a/snmult...  773
# 2      /sc/arion/projects/CommonMind/roussp01a/snmult...  773
# 3      /sc/arion/projects/CommonMind/roussp01a/snmult...  773
# 4      /sc/arion/projects/CommonMind/roussp01a/snmult...  773
# ...                                                  ...  ...
# 14450  /sc/arion/projects/CommonMind/roussp01a/snmult...   13
# 14451  /sc/arion/projects/CommonMind/roussp01a/snmult...   13
# 14452  /sc/arion/projects/CommonMind/roussp01a/snmult...   13
# 14453  /sc/arion/projects/CommonMind/roussp01a/snmult...   13
# 14454  /sc/arion/projects/CommonMind/roussp01a/snmult...    1
#
# [14455 rows x 6 columns]

# %%
len(set(bed_template_df["gene_id"]))
# Out:
# 60576

# %%
bed_template_df = bed_template_df[~bed_template_df["gene_id"].duplicated(keep = "last")]

# %%
bed_template_df[["#chr", "start", "end", "gene_id"]].to_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene_id.unique.gtf","\t",index = False)

# %%
bed_template_df
# Out:
#                   #chr  start    end          gene_id    gene_name
# gene_id
# ENSG00000223972   chr1  11868  11869  ENSG00000223972      DDX11L1
# ENSG00000278267   chr1  17435  17436  ENSG00000278267    MIR6859-1
# ENSG00000243485   chr1  29553  29554  ENSG00000243485  MIR1302-2HG
# ENSG00000227232   chr1  29569  29570  ENSG00000227232       WASH7P
# ENSG00000284332   chr1  30365  30366  ENSG00000284332    MIR1302-2
# ...                ...    ...    ...              ...          ...
# ENSG00000198695  chrMT  14672  14673  ENSG00000198695       MT-ND6
# ENSG00000210194  chrMT  14741  14742  ENSG00000210194        MT-TE
# ENSG00000198727  chrMT  14746  14747  ENSG00000198727       MT-CYB
# ENSG00000210195  chrMT  15887  15888  ENSG00000210195        MT-TT
# ENSG00000210196  chrMT  16022  16023  ENSG00000210196        MT-TP
#
# [60576 rows x 5 columns]

# %%
bed_template_df["gene_id"]
# Out:
# gene_name
# DDX11L1        ENSG00000223972
# MIR6859-1      ENSG00000278267
# MIR1302-2HG    ENSG00000243485
# WASH7P         ENSG00000227232
# MIR1302-2      ENSG00000284332
#                     ...
# MT-ND6         ENSG00000198695
# MT-TE          ENSG00000210194
# MT-CYB         ENSG00000198727
# MT-TT          ENSG00000210195
# MT-TP          ENSG00000210196
# Name: gene_id, Length: 60726, dtype: object

# %%
bed_template_df.to_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.region_list","\t")

# %%
genotype_list = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.genotype_by_chrom_files.txt","\t")
# Out:
# /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
genotype_list["#chr"]= [f'chr{x}' for x in genotype_list["#id"]]

# %%
genotype_list
# Out:
#     #id                                              #path   #chr
# 0     7  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr7
# 1    15  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr15
# 2    10  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr10
# 3     2  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr2
# 4     4  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr4
# 5    22  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr22
# 6     9  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr9
# 7    17  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr17
# 8    12  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr12
# 9     8  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr8
# 10    6  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr6
# 11   16  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr16
# 12    3  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr3
# 13   18  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr18
# 14   19  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr19
# 15   14  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr14
# 16    1  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr1
# 17   21  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr21
# 18   20  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr20
# 19    5  /sc/arion/projects/CommonMind/roussp01a/snmult...   chr5
# 20   11  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr11
# 21   13  /sc/arion/projects/CommonMind/roussp01a/snmult...  chr13

# %%
bed_template_df.merge(genotype_list)[["gene_id","#path"]].rename({"gene_id": "#id"  }, axis = 1).to_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.genotype_by_chrom_files.region_list.txt","\t",index = False)

# %%
bed_template_df.to_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.unique.region_list","\t")

# %%
bed_template_df[]
# Out:
#                   #chr  start    end          gene_id    gene_name
# gene_id
# ENSG00000223972   chr1  11868  11869  ENSG00000223972      DDX11L1
# ENSG00000278267   chr1  17435  17436  ENSG00000278267    MIR6859-1
# ENSG00000243485   chr1  29553  29554  ENSG00000243485  MIR1302-2HG
# ENSG00000227232   chr1  29569  29570  ENSG00000227232       WASH7P
# ENSG00000284332   chr1  30365  30366  ENSG00000284332    MIR1302-2
# ...                ...    ...    ...              ...          ...
# ENSG00000198695  chrMT  14672  14673  ENSG00000198695       MT-ND6
# ENSG00000210194  chrMT  14741  14742  ENSG00000210194        MT-TE
# ENSG00000198727  chrMT  14746  14747  ENSG00000198727       MT-CYB
# ENSG00000210195  chrMT  15887  15888  ENSG00000210195        MT-TT
# ENSG00000210196  chrMT  16022  16023  ENSG00000210196        MT-TP
#
# [60576 rows x 5 columns]

# %%
b = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/MMQTL/Test_data_for_mmQTL/gene_location_for_simulated_phenotype","\t")
# Out:
# /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
b
# Out:
#      1   53679771   53686289     ENSG00000162384
# 0    1  220141943  220220000     ENSG00000136628
# 1    1  229652329  229694442     ENSG00000135776
# 2    1  160370376  160398468     ENSG00000162738
# 3    1  209955661  209957904     ENSG00000162757
# 4    1  206680879  206762616     ENSG00000136653
# ..  ..        ...        ...                 ...
# 794  1  151372010  151374420  ENSG00000159377_A2
# 795  1  183441351  183567381  ENSG00000116698_A4
# 796  1   65713902   65881552  ENSG00000116675_A4
# 797  1  222731244  222763275  ENSG00000143498_A3
# 798  1   32095463   32110497  ENSG00000162517_A2
#
# [799 rows x 4 columns]

# %% [raw]
# !pwd

# %%
a = pd.read_csv("../working/test.csv",",")
# Out:
# /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3508: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
a
# Out:
#                Unnamed: 0              #id  \
# 0     chr12:214119-214120  ENSG00000111181
# 1     chr12:262872-262873  ENSG00000010379
# 2     chr12:389272-389273  ENSG00000120647
# 3     chr12:389319-389320  ENSG00000073614
# 4     chr12:459938-459939  ENSG00000139044
# 5     chr12:663778-663779  ENSG00000171840
# 6     chr12:752578-752579  ENSG00000060237
# 7     chr12:990052-990053  ENSG00000002016
# 8     chr12:990508-990509  ENSG00000082805
# 9     chr12:991189-991190  ENSG00000250132
# 10  chr12:1529890-1529891  ENSG00000111186
#
#                                                 #path  \
# 0   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 1   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 2   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 3   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 4   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 5   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 6   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 7   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 8   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 9   /sc/arion/projects/CommonMind/roussp01a/snmult...
# 10  /sc/arion/projects/CommonMind/roussp01a/snmult...
#
#                                               #dir1_x  \
# 0                                                 NaN
# 1   recipe_testing/data_preprocessing/Astro.EC/phe...
# 2   recipe_testing/data_preprocessing/Astro.EC/phe...
# 3   recipe_testing/data_preprocessing/Astro.EC/phe...
# 4   recipe_testing/data_preprocessing/Astro.EC/phe...
# 5   recipe_testing/data_preprocessing/Astro.EC/phe...
# 6   recipe_testing/data_preprocessing/Astro.EC/phe...
# 7   recipe_testing/data_preprocessing/Astro.EC/phe...
# 8   recipe_testing/data_preprocessing/Astro.EC/phe...
# 9   recipe_testing/data_preprocessing/Astro.EC/phe...
# 10                                                NaN
#
#                                               #dir1_y phenotype_names
# 0   recipe_testing/data_preprocessing/Astro.PFC/ph...              62
# 1   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 2   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 3   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 4                                                 NaN              63
# 5                                                 NaN              63
# 6   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 7   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 8   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 9   recipe_testing/data_preprocessing/Astro.PFC/ph...         63','62
# 10  recipe_testing/data_preprocessing/Astro.PFC/ph...              62

# %%
bed_template_df = load_bed_template('/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/reference_data/Homo_sapiens.GRCh38.103.chr.reformatted.collapse_only.gene.gtf', "gene_name")

# %%
bed_template_df
# Out:
#               #chr  start    end          gene_id    gene_name
# gene_name
# DDX11L1       chr1  11868  11869  ENSG00000223972      DDX11L1
# MIR6859-1     chr1  17435  17436  ENSG00000278267    MIR6859-1
# MIR1302-2HG   chr1  29553  29554  ENSG00000243485  MIR1302-2HG
# WASH7P        chr1  29569  29570  ENSG00000227232       WASH7P
# MIR1302-2     chr1  30365  30366  ENSG00000284332    MIR1302-2
# ...            ...    ...    ...              ...          ...
# MT-ND6       chrMT  14672  14673  ENSG00000198695       MT-ND6
# MT-TE        chrMT  14741  14742  ENSG00000210194        MT-TE
# MT-CYB       chrMT  14746  14747  ENSG00000198727       MT-CYB
# MT-TT        chrMT  15887  15888  ENSG00000210195        MT-TT
# MT-TP        chrMT  16022  16023  ENSG00000210196        MT-TP
#
# [60726 rows x 5 columns]

# %%
genoFile = a

# %%
file_inv = genoFile.drop(columns = ["#id", "phenotype_names"]).to_dict("split")
file_inv['data'] = [[value for value in sublist if not pd.isna(value)] for sublist in file_inv['data']] 


## There will alwayse be genotype file due to left join,
## There will alwayse be covar file as len(covFile) must == len(PhenoFile), and covar column is the same string accross all rows
## So only if there is no bed.gz there will be problem.
regional_data = {"data":file_inv["data"],"meta_info": genoFile[["#id","phenotype_names"]].reset_index().to_dict("split")['data'] }

# Recreate file_inv based on the filtered genoFile
file_inv = genoFile.drop(columns=["#id", "phenotype_names"]).to_dict("split")
file_inv['data'] = [[value for value in sublist if not pd.isna(value)] for sublist in file_inv['data']] 

# Recreate the regional_data based on the filtered data
regional_data = {"data": file_inv["data"],
                 "meta_info": genoFile[["#id", "phenotype_names"]].reset_index().to_dict("split")['data']}

# %%
len(regional_data["data"])
# Out:
# 11

# %%
len(regional_data["meta_info"])
# Out:
# 11

# %%
meta_info = regional_data["meta_info"]

# %%
len(meta_info)
# Out:
# 11

# %%
pd.DataFrame(meta_info,regional_data["data"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[239], line 1
# ----> 1 pd.DataFrame(meta_info,regional_data["data"])
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/frame.py:702, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     693         columns = ensure_index(columns)  # type: ignore[arg-type]
#     694     arrays, columns, index = nested_data_to_arrays(
#     695         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     700         dtype,
#     701     )
# --> 702     mgr = arrays_to_mgr(
#     703         arrays,
#     704         columns,
#     705         index,
#     706         columns,
#     707         dtype=dtype,
#     708         typ=manager,
#     709     )
#     710 else:
#     711     mgr = ndarray_to_mgr(
#     712         data,
#     713         index,
#    (...)
#     717         typ=manager,
#     718     )
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/internals/construction.py:121, in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     119     index = _extract_index(arrays)
#     120 else:
# --> 121     index = ensure_index(index)
#     123 # don't force copy because getting jammed in an ndarray anyway
#     124 arrays = _homogenize(arrays, index, dtype)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/indexes/base.py:6331, in ensure_index(index_like, copy)
#    6328 if len(index_like) and lib.is_all_arraylike(index_like):
#    6329     from pandas.core.indexes.multi import MultiIndex
# -> 6331     return MultiIndex.from_arrays(index_like)
#    6332 else:
#    6333     return Index(index_like, copy=copy, tupleize_cols=False)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/indexes/multi.py:481, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     479 for i in range(1, len(arrays)):
#     480     if len(arrays[i]) != len(arrays[i - 1]):
# --> 481         raise ValueError("all arrays must be same length")
#     483 codes, levels = factorize_from_iterables(arrays)
#     484 if names is lib.no_default:
#
# ValueError: all arrays must be same length

# %%
pos_col = [col for col in a.columns if col.startswith('pos')]
a.index = pd.Series(a[pos_col].values.flatten()).dropna().unique()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 2
#       1 pos_col = [col for col in a.columns if col.startswith('pos')]
# ----> 2 a.index = pd.Series(a[pos_col].values.flatten()).dropna().unique()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/generic.py:5500, in NDFrame.__setattr__(self, name, value)
#    5498 try:
#    5499     object.__getattribute__(self, name)
# -> 5500     return object.__setattr__(self, name, value)
#    5501 except AttributeError:
#    5502     pass
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/generic.py:766, in NDFrame._set_axis(self, axis, labels)
#     764 def _set_axis(self, axis: int, labels: Index) -> None:
#     765     labels = ensure_index(labels)
# --> 766     self._mgr.set_axis(axis, labels)
#     767     self._clear_item_cache()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/internals/managers.py:216, in BaseBlockManager.set_axis(self, axis, new_labels)
#     214 def set_axis(self, axis: int, new_labels: Index) -> None:
#     215     # Caller is responsible for ensuring we have an Index object.
# --> 216     self._validate_set_axis(axis, new_labels)
#     217     self.axes[axis] = new_labels
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/internals/base.py:57, in DataManager._validate_set_axis(self, axis, new_labels)
#      54     pass
#      56 elif new_len != old_len:
# ---> 57     raise ValueError(
#      58         f"Length mismatch: Expected axis has {old_len} elements, new "
#      59         f"values have {new_len} elements"
#      60     )
#
# ValueError: Length mismatch: Expected axis has 14522 elements, new values have 14462 elements

# %%
pd.Series(a[pos_col].values.flatten()).dropna().unique()
# Out:
# array(['chr1:173861-173862;ENSG00000241860',
#        'chr1:778746-778747;ENSG00000237491',
#        'chr1:825137-825138;ENSG00000228794', ...,
#        'chr21:46458890-46458891;ENSG00000160305',
#        'chr21:46605207-46605208;ENSG00000160307',
#        'chr21:46635594-46635595;ENSG00000160310'], dtype=object)

# %%
a["pos1_y"].dropna()
# Out:
# 0             chr1:173861-173862;ENSG00000241860
# 1             chr1:778746-778747;ENSG00000237491
# 2             chr1:825137-825138;ENSG00000228794
# 3             chr1:923922-923923;ENSG00000187634
# 4             chr1:959308-959309;ENSG00000188976
#                           ...
# 14517    chr21:46323874-46323875;ENSG00000160298
# 14518    chr21:46324140-46324141;ENSG00000160299
# 14519    chr21:46458890-46458891;ENSG00000160305
# 14520    chr21:46605207-46605208;ENSG00000160307
# 14521    chr21:46635594-46635595;ENSG00000160310
# Name: pos1_y, Length: 14021, dtype: object

# %%
a["pos1_x"].dropna()
# Out:
# 0             chr1:173861-173862;ENSG00000241860
# 1             chr1:778746-778747;ENSG00000237491
# 2             chr1:825137-825138;ENSG00000228794
# 3             chr1:923922-923923;ENSG00000187634
# 4             chr1:959308-959309;ENSG00000188976
#                           ...
# 14517    chr21:46323874-46323875;ENSG00000160298
# 14518    chr21:46324140-46324141;ENSG00000160299
# 14519    chr21:46458890-46458891;ENSG00000160305
# 14520    chr21:46605207-46605208;ENSG00000160307
# 14521    chr21:46635594-46635595;ENSG00000160310
# Name: pos1_x, Length: 14024, dtype: object

# %%
a["pos3_y"].dropna()
# Out:
# 17          chr1:1399334-1399335;ENSG00000221978
# 32          chr1:1891116-1891117;ENSG00000078369
# 35          chr1:2228318-2228319;ENSG00000157933
# 67          chr1:6785453-6785454;ENSG00000171735
# 69          chr1:7784319-7784320;ENSG00000049246
#                           ...
# 14503    chr21:44873902-44873903;ENSG00000183255
# 14505    chr21:45073852-45073853;ENSG00000197381
# 14513    chr21:46228823-46228824;ENSG00000160285
# 14519    chr21:46458890-46458891;ENSG00000160305
# 14521    chr21:46635594-46635595;ENSG00000160310
# Name: pos3_y, Length: 2694, dtype: object

# %%
a["pos3_x"].dropna()
# Out:
# 0             chr1:173861-173862;ENSG00000241860
# 1             chr1:778746-778747;ENSG00000237491
# 2             chr1:825137-825138;ENSG00000228794
# 3             chr1:923922-923923;ENSG00000187634
# 4             chr1:959308-959309;ENSG00000188976
#                           ...
# 14517    chr21:46323874-46323875;ENSG00000160298
# 14518    chr21:46324140-46324141;ENSG00000160299
# 14519    chr21:46458890-46458891;ENSG00000160305
# 14520    chr21:46605207-46605208;ENSG00000160307
# 14521    chr21:46635594-46635595;ENSG00000160310
# Name: pos3_x, Length: 13633, dtype: object

# %%
sum(a.drop(columns=['#id',"#path"]).isna().sum(axis=1))
# Out:
# 54864

# %%
a.drop(columns=['#id',"#path"]).isna().sum(axis=1).describe()
# Out:
# count    14522.000000
# mean         3.777992
# std          2.474082
# min          0.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max         12.000000
# dtype: float64

# %%
len(set(a["#id"]))
# Out:
# 14462

# %%
import pandas as pd
import qtl.io
from pathlib import Path

def prepare_bed(df, bed_template_df, chr_subset=None):
    bed_df = pd.merge(bed_template_df, df, left_index=True, right_index=True)
    bed_df = bed_df.groupby('#chr', sort=False, group_keys=False).apply(lambda x: x.sort_values('start'))
    if chr_subset is not None:
        bed_df = bed_df[bed_df.chr.isin(chr_subset)]
    return bed_df

def load_and_preprocess_data(input_path, drop_columns):
    df = pd.read_csv(input_path, sep="	", skiprows=0)
    dc = [col for col in df.columns if col in drop_columns] # Take interscet between df.columns and drop_columns
    df = df.drop(dc,axis = 1) # drop the intersect
    if len(df.columns) < 2:
        raise ValueError("There are too few columns in the loaded dataframe, please check the delimiter of the input file. The default delimiter is tab")
    return df

def rename_samples_using_lookup(df, lookup_path):
    sample_participant_lookup = Path(lookup_path)
    if sample_participant_lookup.is_file():
        sample_participant_lookup_s = pd.read_csv(sample_participant_lookup, sep="\t", index_col=1, dtype={0:str,1:str})
        df.rename(columns=sample_participant_lookup_s.to_dict()["genotype_id"], inplace=True)
    return df

def load_bed_template(input_path, phenotype_id_type):
    if sum(qtl.io.gtf_to_tss_bed(input_path, feature='gene', phenotype_id = "gene_id").index.duplicated()) > 0:
        raise valueerror(f"gtf file {input_path} needs to be collapsed into gene model by reference data processing module")

    bed_template_df_id = qtl.io.gtf_to_tss_bed(input_path, feature='transcript', phenotype_id="gene_id")
    bed_template_df_name = qtl.io.gtf_to_tss_bed(input_path, feature='transcript', phenotype_id="gene_name")
    bed_template_df = bed_template_df_id.merge(bed_template_df_name, on=["chr", "start", "end"])
    bed_template_df.columns = ["#chr", "start", "end", "gene_id", "gene_name"]
    bed_template_df = bed_template_df.set_index(phenotype_id_type, drop=False)

    return bed_template_df

# %%
df = load_and_preprocess_data("/hpc/users/sunh14/snmulti_QTL/output/molecular_phenotype/ATAC_dreamlet/pb4dreamlet_subclass_ATAC.SMC.PFC.low_expression_filtered.normalized.log2cpm.gct.gz", ["#chr","chr", "start", "end","stop","annot.seqnames","annot.start","annot.end"]) # This function will drop any columns from the DF based on the drop_columns list, so it is good to make the list comprehensive to accomodate different source of inputs.    df.set_index(df.columns[0], inplace=True)
df.set_index(df.columns[0], inplace=True)
df = rename_samples_using_lookup(df, "/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/snmulti_QTL_sample_participant_lookup_re")
bed_template_df = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/Peak_cell_anno_region_list",sep = "\t").set_index("ID")

# %%
bed_template_df = pd.read_csv("/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/input/Peak_cell_anno_region_list",sep = "\t").set_index("ID")

# %%
bed_template_df = bed_template_df.assign(ID = bed_template_df.index )

# %%
bed_df = prepare_bed(df, bed_template_df)

# %%
bed_df
# Out:
#                           #chr      start        end  \
# chr2:150279268-150279768  chr2  150279268  150279768
# chr2:160306412-160306912  chr2  160306412  160306912
# chr7:96329208-96329708    chr7   96329208   96329708
# chr7:150720416-150720916  chr7  150720416  150720916
#
#                                                 ID  \
# chr2:150279268-150279768  chr2:150279268-150279768
# chr2:160306412-160306912  chr2:160306412-160306912
# chr7:96329208-96329708      chr7:96329208-96329708
# chr7:150720416-150720916  chr7:150720416-150720916
#
#                           G-MSBB-MB000167-BR-MSBB-71808  \
# chr2:150279268-150279768                       7.500654
# chr2:160306412-160306912                       6.105146
# chr7:96329208-96329708                         6.965438
# chr7:150720416-150720916                       7.890160
#
#                           G-MSBB-MB000201-BR-MSBB-71848  \
# chr2:150279268-150279768                       7.958824
# chr2:160306412-160306912                       8.304926
# chr7:96329208-96329708                         8.379874
# chr7:150720416-150720916                       8.583854
#
#                           G-MSBB-MB000269-BR-MSBB-71927  \
# chr2:150279268-150279768                       7.960965
# chr2:160306412-160306912                       7.326377
# chr7:96329208-96329708                         6.166354
# chr7:150720416-150720916                       7.570247
#
#                           G-MSBB-MB000055-BR-MSBB-71689  \
# chr2:150279268-150279768                       8.521975
# chr2:160306412-160306912                       7.640177
# chr7:96329208-96329708                         7.997324
# chr7:150720416-150720916                       7.887813
#
#                           G-MSBB-MB000311-BR-MSBB-71972  \
# chr2:150279268-150279768                       8.124048
# chr2:160306412-160306912                       7.509041
# chr7:96329208-96329708                         6.775259
# chr7:150720416-150720916                       7.303325
#
#                           G-MSBB-MB000165-BR-MSBB-71806  ...  \
# chr2:150279268-150279768                       6.066773  ...
# chr2:160306412-160306912                       6.923105  ...
# chr7:96329208-96329708                         6.557563  ...
# chr7:150720416-150720916                       6.923105  ...
#
#                           G-MSBB-MB000042-BR-MSBB-70672  \
# chr2:150279268-150279768                       8.302691
# chr2:160306412-160306912                       7.475810
# chr7:96329208-96329708                         5.331189
# chr7:150720416-150720916                       6.083383
#
#                           G-MSBB-MB000151-BR-MSBB-71792  \
# chr2:150279268-150279768                       8.538269
# chr2:160306412-160306912                       8.383594
# chr7:96329208-96329708                         8.922314
# chr7:150720416-150720916                       7.785198
#
#                           G-MSBB-MB000099-BR-MSBB-71736  \
# chr2:150279268-150279768                       7.998865
# chr2:160306412-160306912                       7.363166
# chr7:96329208-96329708                         7.363166
# chr7:150720416-150720916                       6.199281
#
#                           G-MSBB-MB000325-BR-MSBB-71986  \
# chr2:150279268-150279768                       3.667575
# chr2:160306412-160306912                       7.956301
# chr7:96329208-96329708                         6.162309
# chr7:150720416-150720916                       8.118001
#
#                           G-MSBB-MB000182-BR-MSBB-71828  \
# chr2:150279268-150279768                       7.252062
# chr2:160306412-160306912                       7.494912
# chr7:96329208-96329708                         6.959891
# chr7:150720416-150720916                       7.702711
#
#                           G-MSBB-MB000318-BR-MSBB-71979  \
# chr2:150279268-150279768                       8.323700
# chr2:160306412-160306912                       7.703955
# chr7:96329208-96329708                         7.496142
# chr7:150720416-150720916                       6.961080
#
#                           G-MSBB-MB000041-BR-MSBB-70665    208754      X565  \
# chr2:150279268-150279768                       7.481947  7.995917  7.756237
# chr2:160306412-160306912                       7.481947  7.306050  6.838632
# chr7:96329208-96329708                         6.088755  7.691831  3.667568
# chr7:150720416-150720916                       8.032315  7.511798  7.756237
#
#                              37563
# chr2:150279268-150279768  7.769193
# chr2:160306412-160306912  7.769193
# chr7:96329208-96329708    7.381899
# chr7:150720416-150720916  8.325868
#
# [4 rows x 45 columns]

# %%
bed_df = bed_df.rename(columns={'gene_id': 'ID'})

# %%
bed_df.reset_index()
# Out:
#                       index  #chr      start        end  \
# 0  chr2:150279268-150279768  chr2  150279268  150279768
# 1  chr2:160306412-160306912  chr2  160306412  160306912
# 2    chr7:96329208-96329708  chr7   96329208   96329708
# 3  chr7:150720416-150720916  chr7  150720416  150720916
#
#    G-MSBB-MB000167-BR-MSBB-71808  G-MSBB-MB000201-BR-MSBB-71848  \
# 0                       7.500654                       7.958824
# 1                       6.105146                       8.304926
# 2                       6.965438                       8.379874
# 3                       7.890160                       8.583854
#
#    G-MSBB-MB000269-BR-MSBB-71927  G-MSBB-MB000055-BR-MSBB-71689  \
# 0                       7.960965                       8.521975
# 1                       7.326377                       7.640177
# 2                       6.166354                       7.997324
# 3                       7.570247                       7.887813
#
#    G-MSBB-MB000311-BR-MSBB-71972  G-MSBB-MB000165-BR-MSBB-71806  ...  \
# 0                       8.124048                       6.066773  ...
# 1                       7.509041                       6.923105  ...
# 2                       6.775259                       6.557563  ...
# 3                       7.303325                       6.923105  ...
#
#    G-MSBB-MB000042-BR-MSBB-70672  G-MSBB-MB000151-BR-MSBB-71792  \
# 0                       8.302691                       8.538269
# 1                       7.475810                       8.383594
# 2                       5.331189                       8.922314
# 3                       6.083383                       7.785198
#
#    G-MSBB-MB000099-BR-MSBB-71736  G-MSBB-MB000325-BR-MSBB-71986  \
# 0                       7.998865                       3.667575
# 1                       7.363166                       7.956301
# 2                       7.363166                       6.162309
# 3                       6.199281                       8.118001
#
#    G-MSBB-MB000182-BR-MSBB-71828  G-MSBB-MB000318-BR-MSBB-71979  \
# 0                       7.252062                       8.323700
# 1                       7.494912                       7.703955
# 2                       6.959891                       7.496142
# 3                       7.702711                       6.961080
#
#    G-MSBB-MB000041-BR-MSBB-70665    208754      X565     37563
# 0                       7.481947  7.995917  7.756237  7.769193
# 1                       7.481947  7.306050  6.838632  7.769193
# 2                       6.088755  7.691831  3.667568  7.381899
# 3                       8.032315  7.511798  7.756237  8.325868
#
# [4 rows x 45 columns]

# %%
bed_df = prepare_bed(df, bed_template_df)

# %%
bed_df.drop_duplicates("ID", keep=False)
# Out:
#                           #chr      start        end  \
# chr2:150279268-150279768  chr2  150279268  150279768
# chr2:160306412-160306912  chr2  160306412  160306912
# chr7:96329208-96329708    chr7   96329208   96329708
# chr7:150720416-150720916  chr7  150720416  150720916
#
#                                                 ID  \
# chr2:150279268-150279768  chr2:150279268-150279768
# chr2:160306412-160306912  chr2:160306412-160306912
# chr7:96329208-96329708      chr7:96329208-96329708
# chr7:150720416-150720916  chr7:150720416-150720916
#
#                           G-MSBB-MB000167-BR-MSBB-71808  \
# chr2:150279268-150279768                       7.500654
# chr2:160306412-160306912                       6.105146
# chr7:96329208-96329708                         6.965438
# chr7:150720416-150720916                       7.890160
#
#                           G-MSBB-MB000201-BR-MSBB-71848  \
# chr2:150279268-150279768                       7.958824
# chr2:160306412-160306912                       8.304926
# chr7:96329208-96329708                         8.379874
# chr7:150720416-150720916                       8.583854
#
#                           G-MSBB-MB000269-BR-MSBB-71927  \
# chr2:150279268-150279768                       7.960965
# chr2:160306412-160306912                       7.326377
# chr7:96329208-96329708                         6.166354
# chr7:150720416-150720916                       7.570247
#
#                           G-MSBB-MB000055-BR-MSBB-71689  \
# chr2:150279268-150279768                       8.521975
# chr2:160306412-160306912                       7.640177
# chr7:96329208-96329708                         7.997324
# chr7:150720416-150720916                       7.887813
#
#                           G-MSBB-MB000311-BR-MSBB-71972  \
# chr2:150279268-150279768                       8.124048
# chr2:160306412-160306912                       7.509041
# chr7:96329208-96329708                         6.775259
# chr7:150720416-150720916                       7.303325
#
#                           G-MSBB-MB000165-BR-MSBB-71806  ...  \
# chr2:150279268-150279768                       6.066773  ...
# chr2:160306412-160306912                       6.923105  ...
# chr7:96329208-96329708                         6.557563  ...
# chr7:150720416-150720916                       6.923105  ...
#
#                           G-MSBB-MB000042-BR-MSBB-70672  \
# chr2:150279268-150279768                       8.302691
# chr2:160306412-160306912                       7.475810
# chr7:96329208-96329708                         5.331189
# chr7:150720416-150720916                       6.083383
#
#                           G-MSBB-MB000151-BR-MSBB-71792  \
# chr2:150279268-150279768                       8.538269
# chr2:160306412-160306912                       8.383594
# chr7:96329208-96329708                         8.922314
# chr7:150720416-150720916                       7.785198
#
#                           G-MSBB-MB000099-BR-MSBB-71736  \
# chr2:150279268-150279768                       7.998865
# chr2:160306412-160306912                       7.363166
# chr7:96329208-96329708                         7.363166
# chr7:150720416-150720916                       6.199281
#
#                           G-MSBB-MB000325-BR-MSBB-71986  \
# chr2:150279268-150279768                       3.667575
# chr2:160306412-160306912                       7.956301
# chr7:96329208-96329708                         6.162309
# chr7:150720416-150720916                       8.118001
#
#                           G-MSBB-MB000182-BR-MSBB-71828  \
# chr2:150279268-150279768                       7.252062
# chr2:160306412-160306912                       7.494912
# chr7:96329208-96329708                         6.959891
# chr7:150720416-150720916                       7.702711
#
#                           G-MSBB-MB000318-BR-MSBB-71979  \
# chr2:150279268-150279768                       8.323700
# chr2:160306412-160306912                       7.703955
# chr7:96329208-96329708                         7.496142
# chr7:150720416-150720916                       6.961080
#
#                           G-MSBB-MB000041-BR-MSBB-70665    208754      X565  \
# chr2:150279268-150279768                       7.481947  7.995917  7.756237
# chr2:160306412-160306912                       7.481947  7.306050  6.838632
# chr7:96329208-96329708                         6.088755  7.691831  3.667568
# chr7:150720416-150720916                       8.032315  7.511798  7.756237
#
#                              37563
# chr2:150279268-150279768  7.769193
# chr2:160306412-160306912  7.769193
# chr7:96329208-96329708    7.381899
# chr7:150720416-150720916  8.325868
#
# [4 rows x 45 columns]

# %%
qtl.io.write_bed(bed_df, "test_atac_output.bed.gz")
# Out:
# /bin/sh: 1: bgzip: not found
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[225], line 1
# ----> 1 qtl.io.write_bed(bed_df, "test_atac_output.bed.gz")
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/qtl/io.py:24, in write_bed(bed_df, output_name, header, float_format)
#      22     header = bed_df.columns.values.copy()
#      23     header[0] = '#chr'
# ---> 24 to_bgzip(bed_df, output_name, header=header, float_format=float_format)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/qtl/io.py:12, in to_bgzip(df, path, header, float_format)
#      10 assert path.endswith('.gz')
#      11 bgzip = subprocess.Popen('bgzip -c > '+path, stdin=subprocess.PIPE, shell=True, encoding='utf8')
# ---> 12 df.to_csv(bgzip.stdin, sep='\t', index=False, header=header, float_format=float_format)
#      13 stdout, stderr = bgzip.communicate()
#      14 subprocess.check_call('tabix -f '+path, shell=True)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/core/generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:257, in CSVFormatter.save(self)
#     237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#    (...)
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
# --> 257     self._save()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:262, in CSVFormatter._save(self)
#     260 if self._need_to_save_header:
#     261     self._save_header()
# --> 262 self._save_body()
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:300, in CSVFormatter._save_body(self)
#     298 if start_i >= end_i:
#     299     break
# --> 300 self._save_chunk(start_i, end_i)
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/io/formats/csvs.py:311, in CSVFormatter._save_chunk(self, start_i, end_i)
#     308 data = [res.iget_values(i) for i in range(len(res.items))]
#     310 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 311 libwriters.write_csv_rows(
#     312     data,
#     313     ix,
#     314     self.nlevels,
#     315     self.cols,
#     316     self.writer,
#     317 )
#
# File /opt/conda/envs/TensorQTL/lib/python3.10/site-packages/pandas/_libs/writers.pyx:75, in pandas._libs.writers.write_csv_rows()
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
bed_df = prepare_bed(df, bed_template_df)
bed_df = bed_df.rename(columns={'gene_id': 'ID'})
qtl.io.write_bed(bed_df, "test_atac_output")
bed_df[["#chr","start","end","ID"]].assign(path = ${_output[0]:r}).to_csv(${_output[1]:r},"\t",index = False)

# %%
data = regional_data["data"]

# %%
zip(meta_info, data)

# %%
genoFile.to_dict("records")
# Out:
# [{'Unnamed: 0': 'chr12:214119-214120',
#   '#id': 'ENSG00000111181',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': nan,
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': '62'},
#  {'Unnamed: 0': 'chr12:262872-262873',
#   '#id': 'ENSG00000010379',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:389272-389273',
#   '#id': 'ENSG00000120647',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:389319-389320',
#   '#id': 'ENSG00000073614',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:459938-459939',
#   '#id': 'ENSG00000139044',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': nan,
#   'phenotype_names': '63'},
#  {'Unnamed: 0': 'chr12:663778-663779',
#   '#id': 'ENSG00000171840',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': nan,
#   'phenotype_names': '63'},
#  {'Unnamed: 0': 'chr12:752578-752579',
#   '#id': 'ENSG00000060237',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:990052-990053',
#   '#id': 'ENSG00000002016',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:990508-990509',
#   '#id': 'ENSG00000082805',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:991189-991190',
#   '#id': 'ENSG00000250132',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': 'recipe_testing/data_preprocessing/Astro.EC/phenotype_data/pb4dreamlet_subclass.Astro.EC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': "63','62"},
#  {'Unnamed: 0': 'chr12:1529890-1529891',
#   '#id': 'ENSG00000111186',
#   '#path': '/sc/arion/projects/CommonMind/roussp01a/snmulti_QTL/output/Genotype/snmulti_QTL_analysis_psychAD_ADSP.leftnorm.bcftools_qc.plink_qc.12.bed',
#   '#dir1_x': nan,
#   '#dir1_y': 'recipe_testing/data_preprocessing/Astro.PFC/phenotype_data/pb4dreamlet_subclass.Astro.PFC.low_expression_filtered.normalized.log2cpm.gct.cov_pca_factor.residual.bed.chr12.bed.gz',
#   'phenotype_names': '62'}]
